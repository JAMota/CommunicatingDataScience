# %% [markdown]
# # Phytoplankton Population Density Analysis

# %% [markdown]
# Import libraries

# %%
import pandas as pd

# %% [markdown]
# Read data

# %%
# Store all dataframes in a dictionary
data = {
    'df2001_03' : pd.read_csv('datasets/phytoplankton-results-april-2001-to-may-2003.csv'),
    'df2003_05' : pd.read_csv('datasets/phytoplankton-results-june-2003-to-july-2005.csv'),
    'df2005_12' : pd.read_csv('datasets/phytoplankton-results-august-2005-to-august-2012.csv'),
    'df2012_16' : pd.read_csv('datasets/phytoplankton-results-september-2012-to-december-2016.csv'),
    'df2017' : pd.read_csv('datasets/phytoplankton-results-january-2017-to-december-2017.csv'),
    'df2018' : pd.read_csv('datasets/phytoplankton-results-january-2018-to-december-2018.csv'),
    'df2019' : pd.read_csv('datasets/phytoplankton-results-january-2019-to-december-2019.csv'),
    'df2020' : pd.read_csv('datasets/phytoplankton-results-january-2020-to-december-2020.csv'),
    'df2021' : pd.read_csv('datasets/phytoplankton-results-january-2021-to-december-2021.csv'),
    'df2022' : pd.read_csv('datasets/phytoplankton-results-january-2022-to-december-2022.csv'),
}
# Display first 2 rows of each df
for (key,value) in data.items():
    print(key)
    display(value.loc[:2,:])
# Out:
# df2001_03
#    SampleId SiteNumber SiteLocation  SampleDate PSP PotentialDirectToxicity  \
# 0       NaN         38        FOWEY  2001-04-02   0                     NaN
# 1       NaN         47        Camel  2001-03-27   0                     NaN
# 2       NaN         52        Conwy  2001-03-28   0                     NaN
#
#   DSP ASP SampleMethod
# 0   0   0          NaN
# 1   0   0          NaN
# 2   0   0          NaN
# df2003_05
#   SampleId  SiteNumber   SiteLocation  SampleDate Alexandrium_sp_PSP  \
# 0       51           1    Holy Island  2003-06-10                  0
# 1       39           6  Wash teetotal  2003-06-05                  0
# 2       40           6       Wash Gat  2003-06-05                  0
#
#   Karenia_mikimotoi_PotentiallyToxicToFish  Protoperidinium_crassipes  \
# 0                                      NaN                        NaN
# 1                                      NaN                        NaN
# ...

# %% [markdown]
# The important features present in all dfs are (renamed): ProductionArea, DateSampleCollected, PSP-Alexandrium, DSP-Dinophysiaceae, DSP-ProrocentrumLima, ASP-Pseudo-nitzschia, YessotoxinLingulodiniumPolyedrum, YessotoxinProtoceratiumReticulatum, VenerupinProrocentrumCordatum

# %%
data[]
